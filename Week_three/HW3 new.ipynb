# %% [markdown]
# **Fraud Detection**
#
# Our tasks
# - Explore the dataset/Visualize
# - Decide which features are important
# - Perform ML
# - Test the model on the testing set

# %%
import numpy as np
import sklearn as sk
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import scale
import random
from sklearn.metrics import classification_report

# %%
import os
os.environ['KAGGLE_USERNAME']="XXXXX"
os.environ['KAGGLE_KEY']="XXXXX"
# !kaggle competitions download -c ieee-fraud-detection
# Out:
# train_transaction.csv.zip: Skipping, found more recently modified local copy (use --force to force download)
# train_identity.csv.zip: Skipping, found more recently modified local copy (use --force to force download)
# test_transaction.csv.zip: Skipping, found more recently modified local copy (use --force to force download)
# test_identity.csv.zip: Skipping, found more recently modified local copy (use --force to force download)
# sample_submission.csv.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !unzip -q train_identity.csv.zip -d data/
# !unzip -q train_transaction.csv.zip -d data/
# !unzip -q test_identity.csv.zip -d data/
# !unzip -q test_transaction.csv.zip -d data/
# Out:
# replace data/train_identity.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace data/train_transaction.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace data/test_identity.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace data/test_transaction.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y

# %%
def create_col_name(base_str, start_int, end_int):
    return [base_str + str(i) for i in range(start_int, end_int + 1)]

# %%
cat_cols = (['ProductCD'] + create_col_name('card', 1, 6) + ['addr1', 'addr2', 'P_emaildomain', 'R_emaildomain'] +
            create_col_name('M', 1, 9) + ['DeviceType', 'DeviceInfo'] + create_col_name('id_', 12, 38))

id_cols = ['TransactionID', 'TransactionDT']

target = 'isFraud'

# %%
type_map = {c: str for c in cat_cols + id_cols}

# %%
df_train_id = pd.read_csv('data/train_identity.csv', dtype=type_map)
df_train_trans = pd.read_csv('data/train_transaction.csv', dtype=type_map)

# %%
df_train_id.shape, df_train_trans.shape
# Out:
# ((144233, 41), (590540, 394))

# %%
df_train_id.head()
# Out:
#   TransactionID  id_01  ...  DeviceType                     DeviceInfo
# 0       2987004    0.0  ...      mobile  SAMSUNG SM-G892A Build/NRD90M
# 1       2987008   -5.0  ...      mobile                     iOS Device
# 2       2987010   -5.0  ...     desktop                        Windows
# 3       2987011   -5.0  ...     desktop                            NaN
# 4       2987016    0.0  ...     desktop                          MacOS
#
# [5 rows x 41 columns]

# %%
df_train = df_train_trans.merge(df_train_id, on='TransactionID', how='left')

# %%
numeric_cols = [col for col in df_train.columns.tolist() if col not in cat_cols + id_cols + [target]]

# %%
assert(df_train.shape[0]==df_train_trans.shape[0])

# %%
df_train.head()
# Out:
#   TransactionID  isFraud  ... DeviceType                     DeviceInfo
# 0       2987000        0  ...        NaN                            NaN
# 1       2987001        0  ...        NaN                            NaN
# 2       2987002        0  ...        NaN                            NaN
# 3       2987003        0  ...        NaN                            NaN
# 4       2987004        0  ...     mobile  SAMSUNG SM-G892A Build/NRD90M
#
# [5 rows x 434 columns]

# %%
df_train[cat_cols].head()
# Out:
#   ProductCD  card1  card2  card3  ... id_35 id_36 id_37 id_38
# 0         W  13926    NaN  150.0  ...   NaN   NaN   NaN   NaN
# 1         W   2755  404.0  150.0  ...   NaN   NaN   NaN   NaN
# 2         W   4663  490.0  150.0  ...   NaN   NaN   NaN   NaN
# 3         W  18132  567.0  150.0  ...   NaN   NaN   NaN   NaN
# 4         H   4497  514.0  150.0  ...     T     F     T     T
#
# [5 rows x 49 columns]

# %%
df_train[numeric_cols].head()
# Out:
#    TransactionAmt  dist1  dist2   C1   C2  ...  id_07  id_08  id_09  id_10  id_11
# 0            68.5   19.0    NaN  1.0  1.0  ...    NaN    NaN    NaN    NaN    NaN
# 1            29.0    NaN    NaN  1.0  1.0  ...    NaN    NaN    NaN    NaN    NaN
# 2            59.0  287.0    NaN  1.0  1.0  ...    NaN    NaN    NaN    NaN    NaN
# 3            50.0    NaN    NaN  2.0  5.0  ...    NaN    NaN    NaN    NaN    NaN
# 4            50.0    NaN    NaN  1.0  1.0  ...    NaN    NaN    NaN    NaN  100.0
#
# [5 rows x 382 columns]

# %% [markdown]
# # Load test data

# %%
df_test_id = pd.read_csv('data/test_identity.csv', dtype=type_map)
df_test_trans = pd.read_csv('data/test_transaction.csv', dtype=type_map)

# %%
df_test_id.head()
# Out:
#   TransactionID  id_01     id_02  ...  id_38  DeviceType                   DeviceInfo
# 0       3663586  -45.0  280290.0  ...      F      mobile  MYA-L13 Build/HUAWEIMYA-L13
# 1       3663588    0.0    3579.0  ...      T      mobile         LGLS676 Build/MXB48T
# 2       3663597   -5.0  185210.0  ...      F     desktop                  Trident/7.0
# 3       3663601  -45.0  252944.0  ...      F      mobile  MYA-L13 Build/HUAWEIMYA-L13
# 4       3663602  -95.0  328680.0  ...      F      mobile         SM-G9650 Build/R16NW
#
# [5 rows x 41 columns]

# %%
df_test = df_test_trans.merge(df_test_id, on='TransactionID', how='left')

# %%
df_test.head()
# Out:
#   TransactionID TransactionDT  TransactionAmt  ... id_38 DeviceType DeviceInfo
# 0       3663549      18403224           31.95  ...   NaN        NaN        NaN
# 1       3663550      18403263           49.00  ...   NaN        NaN        NaN
# 2       3663551      18403310          171.00  ...   NaN        NaN        NaN
# 3       3663552      18403310          284.95  ...   NaN        NaN        NaN
# 4       3663553      18403317           67.95  ...   NaN        NaN        NaN
#
# [5 rows x 433 columns]

# %% [markdown]
# # Next

# %%
fraud = df_train.loc[df_train['isFraud'] == 1]
non_frauds = df_train.loc[df_train['isFraud'] == 0]
print(len(fraud))
print(len(non_frauds))
# Out:
# 20663
# 569877

# %%
ax = fraud.plot.scatter(x='TransactionAmt', y='isFraud', color='Orange', label='Fraud')
non_frauds.plot.scatter(x='TransactionAmt', y='isFraud', color='Blue', label='Normal', ax=ax)
plt.show()

# try different kinds of visualizations

# %%
# time for machine learning!

from sklearn import linear_model
from sklearn.model_selection import train_test_split

# %%
df_train = df_train.dropna('columns')
df_test = df_test.dropna('columns')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_productcd = LabelEncoder()
df_train['ProductCD'] = le_productcd.fit_transform(df_train['ProductCD'])

# %%
#x = df.iloc[:, :-1]
x = df_train.loc[:, df_train.columns != 'isFraud']
y = df_train['isFraud']

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.35)

# could try different test_size arguments

# %%
logistic = linear_model.LogisticRegression(C=1e5)
logistic.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=100000.0, class_weight=None, dual=False,
#                    fit_intercept=True, intercept_scaling=1, l1_ratio=None,
#                    max_iter=100, multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
# on cross-validation set
y_predicted = np.array(logistic.predict(X_test))
print(y_predicted)

# you don't have to use logistic regression as well
# Out:
# [0 0 0 ... 0 0 0]

# %%
print(classification_report(y_test, y_predicted))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98    199539
#            1       0.00      0.00      0.00      7150
#
#     accuracy                           0.97    206689
#    macro avg       0.48      0.50      0.49    206689
# weighted avg       0.93      0.97      0.95    206689

# %%
# on test set. One way: You have to train on the features that training set and test set have in common. And then predict.
le_productcd = LabelEncoder()
df_test['ProductCD'] = le_productcd.fit_transform(df_test['ProductCD'])

y_predicted = np.array(logistic.predict(df_test))
print(y_predicted)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-289ae610a49b> in <module>()
#       2 df_test['ProductCD'] = le_productcd.fit_transform(df_test['ProductCD'])
#       3
# ----> 4 y_predicted = np.array(logistic.predict(df_test))
#       5 print(y_predicted)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/base.py in predict(self, X)
#     287             Predicted class label per sample.
#     288         """
# --> 289         scores = self.decision_function(X)
#     290         if len(scores.shape) == 1:
#     291             indices = (scores > 0).astype(np.int)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/base.py in decision_function(self, X)
#     268         if X.shape[1] != n_features:
#     269             raise ValueError("X has %d features per sample; expecting %d"
# ...
